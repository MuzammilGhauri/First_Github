# %%
# import library
import pandas as pd

#import data from file
chilla = pd.read_csv("Chilla_data2_for_plots.csv")
print(chilla)

# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.set_theme(style="ticks", color_codes=True)

# p= sns.countplot(x="Gender", hue="Age",  data=chilla)
# plt.show()
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %%
# import library
import pandas as pd

#import data from file
chilla = pd.read_csv("Chilla_data2_for_plots.csv")

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

p= sns.countplot(x="What are you?", hue="Age",  data=chilla)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white", context="talk")
chilla = pd.read_csv("Chilla_data2_for_plots.csv")

# Set up the matplotlib figure
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True)

# Generate some sequential data
x = np.array(list("ABCDEFG"))
y1 = np.arange(0, 7)
sns.barplot(x=x, y=y1, palette="rocket", ax=ax1)


# Center the data to make it diverging
y2 = y1 - 3.5
sns.barplot(x=x, y=y2, palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Diverging")

# Randomly reorder the data to make it qualitative
y3 = rs.choice(y1, len(y1), replace=False)
sns.barplot(x=x, y=y3, palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Qualitative")

# Finalize the plot
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13196/453883275.py in <module>
#      21
#      22 # Randomly reorder the data to make it qualitative
# ---> 23 y3 = rs.choice(y1, len(y1), replace=False)
#      24 sns.barplot(x=x, y=y3, palette="deep", ax=ax3)
#      25 ax3.axhline(0, color="k", clip_on=False)
#
# NameError: name 'rs' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool=sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool=sns.load_dataset("iris")
sns.lineplot(x="sepal_length", y="sepal_width", hue="petal_width", data=phool)
plt.xlabel("Patton ki lambai")
plt.ylabel("Patton ki chorai")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

#**Result:**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0, 60])
y=np.array([25, 250])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

x=np.array([2,4,8,10])
y=np.array([1,4,8,15])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

x=np.array([2,4,8,10])
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd


a=np.array([1,4,8,15])
plt.plot(a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

x=np.array([2,8,3,10])
y=np.array([1,3,11,5])
plt.plot(x, "p--r", ms=10, linewidth=2)
plt.plot(y, "h--b", ms=10, linewidth=2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

x1=np.array([2,8,3,10])
x2=np.array([5,8,10,17])
y1=np.array([3,9,12,16])
y2=np.array([1,3,11,5])
plt.plot(x1, y1, x2, y2)
plt.xlabel("yabrhiaan")
plt.ylabel("shabriyaan")
plt.title("Khabriaan", loc="center", fontsize=20)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([1,5, 15, 26,35])
x1
y1=np.array([6,1,16,2,23])
y1
plt.subplot(1, 1, 1)
plt.plot(x1, y1, "h--r")
