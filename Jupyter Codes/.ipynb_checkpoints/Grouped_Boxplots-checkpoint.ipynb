# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
chill = pd.read_csv("Chilla_data2_for_plots.csv")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Your favorite programming language?", y="Age (years)-Float/Int",
            hue="Marital Status?", palette=["r", "b"],
            data=chill)
plt.ylim(13, 45)
# Out:
# (13.0, 45.0)
