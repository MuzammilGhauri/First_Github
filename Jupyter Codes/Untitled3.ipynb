# %%
# 1- Headings
How to give headings in markdown files
# Heading 1
## Heading 2
### Heading 3
#### Heading 4
##### Heading 5
###### Heading 6

# 2- Normal Text


This is a normal text. 

this is also a normal text

# 3-Special Text

>This is a special text
>
>This is also a special text

# 4- Combing above three things

> # Special Heading
> Special text
> Everything Special

# 5-Line Breaks

By pressing double enter or by adding \ symbol at the end of any statement

# 5- Face of Text

## Bold and Italic rules

**Bold**

*Italic*

***Bold and Italic***

__Bold__

_Italic_

___Bold and italic___

# 6- Bulet Points / List
- Day 1
- Day 2
- Day 3
- Day 4
- Day 5
    - Day 5A   
        - Day 5A(i)
    - Day 5B
- Day 6
- Day 7
* Day 8
+ Day 9
> __Using * and +__
 

> # 7- Numbering of List

1. Day 1
2. Day 2
3. Day 3
4. Day 4
    1. Day 4a
    2. Day 4b
5. Day 5
6. Day 6

# Line or Page Breaks

I want to draw line between this line.

---
___
***
and this line.

# Links and Hyperlinks

to give link of a webite, type <> and add the link inside <>

<https://www.youtube.com/watch?v=qJqAXjz-Rh4>

to give link as a hyperlink on another word without showing the website link, add the word or sentence between [] and immediately after the [], add () and paste the website link inside ()

The link for python tutotrials is [here](https://www.tutorialsteacher.com/python/set-methods)

you can also assign a name to a link and write it inside [] followed by : pasting the link after thus. this name can then be used instead of pasting complete link. e.g

[zainab]:https://www.tutorialsteacher.com/python/set-methods

the link is [here][zainab]

# ADDING IMAGE OR FILE

Image can be added by assigning it a name, writing that name inside [] and immediately after that, adding image name inside () however, the image or any file must be stored inside the folder where this markdown file is stored. e.g
 I want to upload My [Pic](DSC_001888.png)

 or online [pic](https://www.google.com/search?q=nudes&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi6w6OV4aL1AhWKy4UKHWMmDCAQ_AUoAXoECAIQAw&biw=1366&bih=625&dpr=1#imgrc=NkQKfmYvhmTdcM)

# Writing code in markdown

To print a string, use backtick before and after code `

and to make a code block, use back tick thrice before and after code

`print("what are you upto")`


```R
a = "My name is string"
b = "I am also a string but c is a number"
c = 2 + 3
print(a, b, c)
```
> You can separate two code blocks in this manner. Writing the name of programming language changes the colour of code into the respective language

```python
a = "zainab"
b = "salaar"
c = a + b
print(c)
```

# Adding Tables
Add | before and after every heading or box in a table

Draw three dashes in second line to draw line under the heading

add all contents of table with | before and after contents of every box

Aligh the contents of box in left, right or centre by adding colon at left, right or both sides of the dashes line respectively

|  S No |   Rank |     Name |    Pak |    Branch |
|:---:   |:---: |:---- |    :---: |     :-----: |
| 1  | Sqn Ldr | Muzammil | 15202 | Engg |
| 1  | Sqn Ldr | Waqar | 14681 | Engg |
| 1  | Sqn Ldr | kaleem | 17833 | Engg |
| 1  | Sqn Ldr | irfan | 15202 | Engg |
| 1  | Wg Cdr | Hammad | 13242 | Engg |
| 1  | Sqn Ldr | Imran | 12345 | Log |

# Table of Contents

Write the item in square bracket [] that you want to add in table of content. then add round brackets and write the word or sentence that you want to link. all spaces must be replaced with dashes)

[1-Normal Text](#2--normal-text)

[2-Adding Table](#adding-tables)

[3-Adding Image or File](#adding-image-or-file)

# Install Extensions

**sample text**

**sample text**

_italic text_

**_italic and bold_**

[Link](https://www.google.com/search?q=mercedes&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi27PrMnqT1AhV3Q_EDHavtAVUQ_AUoAXoECAMQAw&biw=1366&bih=625&dpr=1#imgrc=OPLYiygiyAUBXM)

[image](DSC_001888.png)

* Toggle bullet points
* ~~strikethrough~~
```
a=2+3
b= 3+4
print(a+b)
```
`print("string")`

> Zainab is my daughter\
> salaar is my son\
>

Column A | Column B | Column C
---------|----------|---------
 A1 | B1 | C1
 A2 | B2 | C2
 AC3 | B3 | C3


Column A | Column B | Column C
---------|----------|---------
 A1 | B1 | C1
 A2 | B2 | C2
 A3 | B3 | C3

- [ ] Plz tick the best option
- [ ] plz check it

> Coloring Text 

<span style="color:green">
I love my kids\
</span>

>Inline_Maths

$this_{is}^3$

>Maths Equations 

$$ \int_0^\infty\frac{x^3}{e^3-1}\,dx= \frac{\pi^4}{15} $$

You can see MathJax on google for more details about writing equation [Mathjax](https://www.mathjax.org/)
